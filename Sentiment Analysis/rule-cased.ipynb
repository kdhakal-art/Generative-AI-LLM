# %% [markdown]
# It uses a set of predefined rules to analyze sentiment. These rules are based on linguistic patterns and are designed to capture common expressions of positive, negative, or neutral sentiment. The system applies these rules to text data to determine the sentiment score.

# %%
sentence_1 = "i had a great time at the movie it was really funny"
sentence_2 = "i had a great time at the movie but the parking was terrible"
sentence_3 = "i had a great time at the movie but the parking wasn't great"
sentence_4 = "i went to see a movie"

# %% [markdown]
# TextBlob

# %%
# !pip install textblob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from textblob import TextBlob

# %%
print(sentence_1)
sentiment_score_1 = TextBlob(sentence_1).sentiment.polarity
print(sentiment_score_1)
# Out:
# i had a great time at the movie it was really funny
# 0.525

# %%
print(sentence_2)
sentiment_score_2 = TextBlob(sentence_2).sentiment.polarity
print(sentiment_score_2)
# Out:
# i had a great time at the movie but the parking was terrible
# -0.09999999999999998

# %% [markdown]
# VADER

# %%
# !pip install vaderSentiment
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached vaderSentiment-3.3.2-py2.py3-none-any.whl.metadata (572 bytes)
# ...
# Using cached vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
# ...
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
vader_sentiment = SentimentIntensityAnalyzer()

# %%
print(sentence_1)
print(vader_sentiment.polarity_scores(sentence_1))
# Out:
# i had a great time at the movie it was really funny
# {'neg': 0.0, 'neu': 0.578, 'pos': 0.422, 'compound': 0.807}
